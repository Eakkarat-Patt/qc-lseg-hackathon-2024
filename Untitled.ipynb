# %%
import pandas as pd

# %%
df = pd.read_csv('esg.csv')

# %%
df[df.Instrument=='PTT.BK']
# Out:
#       Unnamed: 0 Instrument  ESG Score        Date  \
# 4255        4255     PTT.BK  72.334995  2015-12-31
# 4256        4256     PTT.BK  70.153726  2016-12-31
# 4257        4257     PTT.BK  75.698198  2017-12-31
# 4258        4258     PTT.BK  76.238607  2018-12-31
# 4259        4259     PTT.BK  76.542837  2019-12-31
# 4260        4260     PTT.BK  74.309207  2020-12-31
# 4261        4261     PTT.BK  75.713280  2021-12-31
# 4262        4262     PTT.BK  78.948779  2022-12-31
#
#       Environmental Pillar Score  Governance Pillar Score  \
# 4255                   92.549351                40.005447
# 4256                   93.302235                34.028644
# 4257                   92.895681                54.028455
# 4258                   94.106746                34.444444
# 4259                   93.099104                41.351916
# 4260                   93.130043                40.091339
# 4261                   92.764553                48.229547
# ...

# %%
df
# Out:
#       Unnamed: 0  Instrument  ESG Score        Date  \
# 0              0    24CSm.BK        NaN         NaN
# 1              1   24CSmf.BK        NaN         NaN
# 2              2  24CSmol.BK        NaN         NaN
# 3              3  24CSmva.BK        NaN         NaN
# 4              4       2S.BK        NaN         NaN
# ...          ...         ...        ...         ...
# 6563        6563    ZENva.BK  51.265119  2022-12-31
# 6564        6564    ZIGAm.BK        NaN         NaN
# 6565        6565   ZIGAmf.BK        NaN         NaN
# 6566        6566  ZIGAmol.BK        NaN         NaN
# 6567        6567  ZIGAmva.BK        NaN         NaN
#
#       Environmental Pillar Score  Governance Pillar Score  \
# 0                            NaN                      NaN
# 1                            NaN                      NaN
# 2                            NaN                      NaN
# 3                            NaN                      NaN
# ...
