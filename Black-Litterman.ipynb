# %%
from matplotlib import pyplot as plt
import yfinance as yf
import pandas as pd
import plotly.express as px

from pypfopt import EfficientFrontier, objective_functions
from pypfopt import black_litterman, risk_models
from pypfopt import BlackLittermanModel
from pypfopt import DiscreteAllocation
import seaborn as sns

# %%
from pypfopt import plotting

# %%
symbols = [
    'AAPL',
    'MSFT',
    'META',
    'AMZN',
    'XOM',
    'UNH',
    'JNJ',
    'V',
    'HD',
    'ABBV',
    'KO',
    'DIS',
    'T',
    'UPS',
    'LMT',
    'CAT',
    'F',
    'MAR',
    'O',
    'HSY'
]

# %%
portfolio = yf.download(symbols, start="2018-01-01", end="2023-02-28")['Adj Close']

portfolio.head()
# Out:
# c:\Users\Eakka\anaconda3\envs\portopt\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# c:\Users\Eakka\anaconda3\envs\portopt\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [                       0%%                      ]c:\Users\Eakka\anaconda3\envs\portopt\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# c:\Users\Eakka\anaconda3\envs\portopt\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*******               15%%                      ]  3 of 20 completedc:\Users\Eakka\anaconda3\envs\portopt\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [**********            20%%                      ]  4 of 20 completedc:\Users\Eakka\anaconda3\envs\portopt\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# c:\Users\Eakka\anaconda3\envs\portopt\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [**************        30%%                      ]  6 of 20 completedc:\Users\Eakka\anaconda3\envs\portopt\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*****************     35%%                      ]  7 of 20 completedc:\Users\Eakka\anaconda3\envs\portopt\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# c:\Users\Eakka\anaconda3\envs\portopt\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*******************   40%%                      ]  8 of 20 completedc:\Users\Eakka\anaconda3\envs\portopt\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [**********************45%%                      ]  9 of 20 completedc:\Users\Eakka\anaconda3\envs\portopt\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# c:\Users\Eakka\anaconda3\envs\portopt\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# c:\Users\Eakka\anaconda3\envs\portopt\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [**********************65%%*****                 ]  13 of 20 completedc:\Users\Eakka\anaconda3\envs\portopt\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# c:\Users\Eakka\anaconda3\envs\portopt\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [**********************75%%**********            ]  15 of 20 completedc:\Users\Eakka\anaconda3\envs\portopt\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [**********************80%%************          ]  16 of 20 completedc:\Users\Eakka\anaconda3\envs\portopt\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [**********************85%%***************       ]  17 of 20 completedc:\Users\Eakka\anaconda3\envs\portopt\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [**********************90%%*****************     ]  18 of 20 completedc:\Users\Eakka\anaconda3\envs\portopt\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  20 of 20 completed
# Ticker           AAPL       ABBV       AMZN         CAT         DIS         F  \
# Date
# 2018-01-02  40.670986  74.280701  59.450500  135.362320  108.372864  9.247079
# 2018-01-03  40.663891  75.443092  60.209999  135.569183  108.838135  9.320119
# 2018-01-04  40.852779  75.012840  60.479500  137.431000  108.789680  9.480809
# 2018-01-05  41.317894  76.318680  61.457001  139.603180  108.198380  9.641503
# 2018-01-08  41.164429  75.095886  62.343498  143.111313  106.647415  9.604980
#
# Ticker              HD        HSY         JNJ         KO         LMT  \
# Date
# 2018-01-02  162.567657  97.810402  117.502693  37.655872  271.792267
# 2018-01-03  163.414978  97.400383  118.625137  37.573174  274.070435
# 2018-01-04  164.711807  98.080887  118.616722  38.102379  278.771881
# 2018-01-05  166.432327  98.552010  119.595711  38.094116  281.297485
# 2018-01-08  166.034653  99.511681  119.747612  38.036228  280.000488
#
# Ticker             MAR        META       MSFT          O          T  \
# Date
# 2018-01-02  127.620232  181.419998  80.080910  41.653717  17.768679
# 2018-01-03  130.196487  184.669998  80.453613  41.543365  17.358349
# 2018-01-04  129.480835  184.330002  81.161720  40.645847  17.519714
# 2018-01-05  128.240448  186.850006  82.167953  40.616432  17.584263
# 2018-01-08  130.091583  188.279999  82.251816  40.667904  17.634974
#
# Ticker             UNH         UPS           V        XOM
# Date
# 2018-01-02  202.505478  100.919220  109.733643  62.638451
# 2018-01-03  204.629761  103.155151  110.826096  63.868675
# 2018-01-04  205.517975  103.824318  111.238167  63.957081
# 2018-01-05  209.436905  104.142578  113.902214  63.905510
# 2018-01-08  205.801819  105.407433  114.362175  64.192833

# %%
market_prices = yf.download("SPY", start='2018-01-01', end='2023-02-28')["Adj Close"]
market_prices.head()
# Out:
# c:\Users\Eakka\anaconda3\envs\portopt\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed
# Date
# 2018-01-02    243.072281
# 2018-01-03    244.609741
# 2018-01-04    245.640701
# 2018-01-05    247.277603
# 2018-01-08    247.729843
# Name: Adj Close, dtype: float64
